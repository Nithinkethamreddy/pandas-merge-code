# %% [markdown]
# <a href="https://colab.research.google.com/github/Nithinkethamreddy/pandas-merge-code/blob/main/Pandas_merge_and_append.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
### Merge and Append

# %%
import pandas as pd

# %%
pd
# Out:
# <module 'pandas' from '/usr/local/lib/python3.11/dist-packages/pandas/__init__.py'>

# %%
# First DataFrame: Marks
df1 = pd.DataFrame({
    'Name': ['A', 'B', 'C', 'D'],
    'age': [19, 20, 22, 24],


    'Marks': [10, 20, 30, 40]
})
# Second DataFrame: Gender
df2 = pd.DataFrame({
    'Name': ['A', 'B', 'D', 'E', 'F'],
    'Gender': ['Male', 'Female', 'Male', 'Female','Male']
})

# %%
df1
# Out:
#   Name  age  Marks
# 0    A   19     10
# 1    B   20     20
# 2    C   22     30
# 3    D   24     40

# %%
df2
# Out:
#   Name  Gender
# 0    A    Male
# 1    B  Female
# 2    D    Male
# 3    E  Female
# 4    F    Male

# %%
pd.merge(df1,df2,on=['Name'],how='inner')
# Out:
#   Name  age  Marks  Gender
# 0    A   19     10    Male
# 1    B   20     20  Female
# 2    D   24     40    Male

# %%
pd.merge(df1,df2,on=['Name'],how='outer')
# Out:
#   Name   age  Marks  Gender
# 0    A  19.0   10.0    Male
# 1    B  20.0   20.0  Female
# 2    C  22.0   30.0     NaN
# 3    D  24.0   40.0    Male
# 4    E   NaN    NaN  Female
# 5    F   NaN    NaN    Male

# %%
# First DataFrame: Marks
df1 = pd.DataFrame({
    'Name': ['A', 'A', 'C', 'D'],
    'Marks': [10, 20, 30, 40]
})

# Second DataFrame: Gender
df2 = pd.DataFrame({
    'Name': ['A', 'A', 'A', 'E', 'F'],
    'Gender': ['Male', 'Female', 'Male', 'Female','Male']
})

# %%
df1
# Out:
#   Name  Marks
# 0    A     10
# 1    A     20
# 2    C     30
# 3    D     40

# %%
pd.merge(df1,df2,on=['Name'],how='inner')
# Out:
#   Name  Marks  Gender
# 0    A     10    Male
# 1    A     10  Female
# 2    A     10    Male
# 3    A     20    Male
# 4    A     20  Female
# 5    A     20    Male

# %%
import pandas as pd

# Sales Transactions Table
df_sales = pd.DataFrame({
    'CustomerID': ['A', 'A', 'C', 'D'],
    'TransactionAmount': [10, 20, 30, 40],
    'TransactionID': ['T001', 'T002', 'T003', 'T004'],
    'Date': ['2024-06-01', '2024-06-05', '2024-06-07', '2024-06-08']
})

# %%
# Customer Details Table
df_customers = pd.DataFrame({
    'CustomerID': ['A', 'A', 'B', 'D', 'D'],
    'Gender': ['Male', 'Female', 'Male', 'Female', 'Male'],
    'Location': ['Mumbai', 'Mumbai', 'Delhi', 'Chennai','Hyderabad']
})

# %%
df_sales
# Out:
#   CustomerID  TransactionAmount TransactionID        Date
# 0          A                 10          T001  2024-06-01
# 1          A                 20          T002  2024-06-05
# 2          C                 30          T003  2024-06-07
# 3          D                 40          T004  2024-06-08

# %%
pd.merge(df_sales,df_customers,on='CustomerID',how='inner')
# Out:
#   CustomerID  TransactionAmount TransactionID        Date  Gender   Location
# 0          A                 10          T001  2024-06-01    Male     Mumbai
# 1          A                 10          T001  2024-06-01  Female     Mumbai
# 2          A                 20          T002  2024-06-05    Male     Mumbai
# 3          A                 20          T002  2024-06-05  Female     Mumbai
# 4          D                 40          T004  2024-06-08  Female    Chennai
# 5          D                 40          T004  2024-06-08    Male  Hyderabad

# %%
df_customers
# Out:
#   CustomerID  Gender   Location
# 0          A    Male     Mumbai
# 1          A  Female     Mumbai
# 2          B    Male      Delhi
# 3          D  Female    Chennai
# 4          D    Male  Hyderabad

# %%
df1
# Out:
#   Name  Marks
# 0    A     10
# 1    A     20
# 2    C     30
# 3    D     40

# %%
df2
# Out:
#   Name  Gender
# 0    A    Male
# 1    A  Female
# 2    A    Male
# 3    E  Female
# 4    F    Male

# %%
pd.merge(df1,df2,on='Name',how='left')
# Out:
#   Name  Marks  Gender
# 0    A     10    Male
# 1    A     10  Female
# 2    A     10    Male
# 3    A     20    Male
# 4    A     20  Female
# 5    A     20    Male
# 6    C     30     NaN
# 7    D     40     NaN

# %%
pd.merge(df1,df1,on='Name',how='right')
# Out:
#   Name  Marks_x  Marks_y
# 0    A       10       10
# 1    A       20       10
# 2    A       10       20
# 3    A       20       20
# 4    C       30       30
# 5    D       40       40

# %%
pd.merge(df2,df1,on='Name',how='right')
# Out:
#   Name  Gender  Marks
# 0    A    Male     10
# 1    A  Female     10
# 2    A    Male     10
# 3    A    Male     20
# 4    A  Female     20
# 5    A    Male     20
# 6    C     NaN     30
# 7    D     NaN     40

# %%
pd.merge(df2,df1,on='Name',how='left',indicator=True)
# Out:
#   Name  Gender  Marks     _merge
# 0    A    Male   10.0       both
# 1    A    Male   20.0       both
# 2    A  Female   10.0       both
# 3    A  Female   20.0       both
# 4    A    Male   10.0       both
# 5    A    Male   20.0       both
# 6    E  Female    NaN  left_only
# 7    F    Male    NaN  left_only

# %%
df1.values
# Out:
# array([['A', 10],
#        ['A', 20],
#        ['C', 30],
#        ['D', 40]], dtype=object)

# %%
x=[1,2,3]
y=[4,5,6]

# %%
print(x,y)
# Out:
# [1, 2, 3] [4, 5, 6]

# %%
for i in df1.values:
  for j in df2.values:
    print(list(i),list(j))
# Out:
# ['A', 10] ['A', 'Male']
# ['A', 10] ['A', 'Female']
# ['A', 10] ['A', 'Male']
# ['A', 10] ['E', 'Female']
# ['A', 10] ['F', 'Male']
# ['A', 20] ['A', 'Male']
# ['A', 20] ['A', 'Female']
# ['A', 20] ['A', 'Male']
# ['A', 20] ['E', 'Female']
# ['A', 20] ['F', 'Male']
# ['C', 30] ['A', 'Male']
# ['C', 30] ['A', 'Female']
# ['C', 30] ['A', 'Male']
# ['C', 30] ['E', 'Female']
# ['C', 30] ['F', 'Male']
# ['D', 40] ['A', 'Male']
# ['D', 40] ['A', 'Female']
# ['D', 40] ['A', 'Male']
# ['D', 40] ['E', 'Female']
# ['D', 40] ['F', 'Male']

# %%
df1['constant']=1
df2['constant']=1

# %%
df1
# Out:
#   Name  Marks  consrant  constant
# 0    A     10         1         1
# 1    A     20         1         1
# 2    C     30         1         1
# 3    D     40         1         1

# %%
df2
# Out:
#   Name  Gender  constant
# 0    A    Male         1
# 1    A  Female         1
# 2    A    Male         1
# 3    E  Female         1
# 4    F    Male         1

# %%
pd.merge(df1,df2,on='constant',how='inner')
# Out:
#    Name_x  Marks  consrant  constant Name_y  Gender
# 0       A     10         1         1      A    Male
# 1       A     10         1         1      A  Female
# 2       A     10         1         1      A    Male
# 3       A     10         1         1      E  Female
# 4       A     10         1         1      F    Male
# 5       A     20         1         1      A    Male
# 6       A     20         1         1      A  Female
# 7       A     20         1         1      A    Male
# 8       A     20         1         1      E  Female
# 9       A     20         1         1      F    Male
# 10      C     30         1         1      A    Male
# 11      C     30         1         1      A  Female
# 12      C     30         1         1      A    Male
# 13      C     30         1         1      E  Female
# 14      C     30         1         1      F    Male
# 15      D     40         1         1      A    Male
# 16      D     40         1         1      A  Female
# ...

# %%
# Customers Table
df_customers = pd.DataFrame({
    'CustomerID': ['A', 'B', 'C', 'D', 'E'],
    'CustomerName': ['Alice', 'Bob', 'Charlie', 'David', 'Eve']
})

# Merge the DataFrames
merged_df = pd.merge(df_sales, df_customers, on='CustomerID', how='inner')
display(merged_df)
